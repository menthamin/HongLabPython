# %% [markdown]
# ### 딥러닝 간단하게 체험해보기 ###
# - [AnimeGAN v2 파이토치 구현](https://github.com/bryandlee/animegan2-pytorch)
# - [Pytorch 설치 방법](https://pytorch.org/)

# %%
import torch
from PIL import Image

img = Image.open("jmhong_face.png").convert("RGB")

def run(img, pretrained):
    model = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained=pretrained)
    face2paint = torch.hub.load("bryandlee/animegan2-pytorch:main", "face2paint", size=512)
    out = face2paint(model, img)
    display(out)

run(img, "celeba_distill")
# Out:
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x231B137B820>

# %%
run(img, "face_paint_512_v1")
# Out:
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x231B0B14400>

# %%
run(img, "face_paint_512_v2")
# Out:
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x231B0B14430>

# %%
run(img, "paprika")
# Out:
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# Using cache found in C:\Users\jmhong/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x231B0B14730>
