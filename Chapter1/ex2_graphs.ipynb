# %% [markdown]
# ### Matplotlib을 이용해서 그래프를 그려봅시다.
#
# [Matplotlib 갤러리 링크](https://matplotlib.org/stable/gallery/index.html)

# %% [markdown]
# #### [Plotting categorical variables](https://matplotlib.org/stable/gallery/lines_bars_and_markers/categorical_variables.html#sphx-glr-gallery-lines-bars-and-markers-categorical-variables-py) 예제를 그대로 복사해서 붙여봅시다.
